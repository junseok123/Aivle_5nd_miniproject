# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계2 : 기본 모델링

# %% [markdown]
# ## 0.미션

# %% [markdown]
# * 데이터 전처리
#     * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리 수행
# * 다양한 알고리즘으로 분류 모델 생성
#     * 최소 4개 이상의 알고리즘을 적용하여 모델링 수행
#     * 성능 비교
#     * 각 모델의 성능을 저장하는 별도 데이터 프레임을 만들고 비교
# * 옵션 : 다음 사항은 선택사항입니다. 시간이 허용하는 범위 내에서 수행하세요.
#     * 상위 N개 변수를 선정하여 모델링 및 성능 비교
#         * 모델링에 항상 모든 변수가 필요한 것은 아닙니다.
#         * 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교하세요.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것입니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %% [markdown]
# * 세부 요구사항
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#     - 필요하다고 판단되는 라이브러리를 추가하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# * 함수 생성

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (2) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
# * 세부 요구사항
#     - 전체 데이터 'data01_train.csv' 를 불러와 'data' 이름으로 저장합니다.
#         - data에서 변수 subject는 삭제합니다.
#     - 데이터프레임에 대한 기본 정보를 확인합니다.( .head(), .shape 등)

# %% [markdown]
# #### 1) 데이터 로딩

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/2023.04.12_미니프로젝트5차_3_5일차 실습자료/data01_train.csv')

# %%
data.isnull().sum()
# Out:
# tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 563, dtype: int64

# %%
data.drop('subject',axis=1,inplace=True)

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5881 entries, 0 to 5880
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 25.2+ MB

# %% [markdown]
# ## **2. 데이터 전처리**
#
# * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리를 수행한다.

# %% [markdown]
# ### (1) 데이터 분할1 : x, y

# %% [markdown]
# * 세부 요구사항
#     - x, y로 분할합니다.

# %%
target = 'Activity'
x =data.drop(target,axis=1)
y=data.loc[:,target]

# %%
y
# Out:
# 0                 STANDING
# 1                   LAYING
# 2                 STANDING
# 3                  WALKING
# 4       WALKING_DOWNSTAIRS
#                ...
# 5876               SITTING
# 5877      WALKING_UPSTAIRS
# 5878                LAYING
# 5879      WALKING_UPSTAIRS
# 5880               SITTING
# Name: Activity, Length: 5881, dtype: object

# %% [markdown]
# ### (2) 스케일링(필요시)

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %% [markdown]
# ### (3) 데이터분할2 : train, validation

# %% [markdown]
# * 세부 요구사항
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycaret
#   Downloading pycaret-3.0.0-py3-none-any.whl (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.8.0)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.3.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.1.2)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.13.5)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.2.0)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.13.1)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.5)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.7.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.2.1)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.56.4)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 6.1 MB/s eta 0:00:00
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.9/dist-packages (from pycaret) (7.7.1)
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.27.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (7.34.0)
# Collecting plotly-resampler>=0.8.3.1
#   Downloading plotly_resampler-0.8.3.2.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 7.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.22.4)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (4.65.0)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.5.3)
# Collecting schemdraw>=0.14
#   Downloading schemdraw-0.16-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 kB 15.1 MB/s eta 0:00:00
# Collecting pyod>=1.0.8
#   Downloading pyod-1.0.9.tar.gz (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 20.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (6.2.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.10.1)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.10.1)
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.9.4)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.2.2)
# Collecting sktime>=0.16.1
#   Downloading sktime-0.17.1-py3-none-any.whl (16.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 80.6 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from deprecation>=2.1.0->pycaret) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn>=0.8.1->pycaret) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.15.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (67.6.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (2.14.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (3.0.38)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.6.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.0.7)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->pycaret) (0.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (4.3.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.8.10-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 16.1 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 21.6 MB/s eta 0:00:00
# Collecting jupyter-dash>=0.4.2
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting dash<3.0.0,>=2.2.0
#   Downloading dash-2.9.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.15)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.34)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (2.0.12)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.9/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.2.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.4.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.2.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (23.2.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Building wheels for collected packages: plotly-resampler, pyod
#   Building wheel for plotly-resampler (pyproject.toml) ... done
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3.2-cp39-cp39-manylinux_2_31_x86_64.whl size=75049 sha256=5954c9948ee51cd0c66745c82c93b3e355f95a98e7b7dfd8aad1bdc7a81c8fce
#   Stored in directory: /root/.cache/pip/wheels/9e/36/06/4c11e300918011376af149098621ec7ebe06d8256566d43d51
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.9-py3-none-any.whl size=184112 sha256=abe6d031a3b4767f8c2d5c2fc10cad93bae8aafcbd3b0053846f81a5ace58c44
#   Stored in directory: /root/.cache/pip/wheels/1b/9c/b8/9759d7cc64a1e01bb9872ade80cb7db445ccf506e083325106
# Successfully built plotly-resampler pyod
# Installing collected packages: trace-updater, kaleido, dash-table, dash-html-components, dash-core-components, xxhash, wurlitzer, schemdraw, retrying, orjson, jedi, deprecation, deprecated, ansi2html, sktime, scikit-plot, pyod, dash, pmdarima, jupyter-dash, category-encoders, tbats, plotly-resampler, pycaret
# Successfully installed ansi2html-1.8.0 category-encoders-2.6.0 dash-2.9.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.13 deprecation-2.1.0 jedi-0.18.2 jupyter-dash-0.4.2 kaleido-0.2.1 orjson-3.8.10 plotly-resampler-0.8.3.2 pmdarima-2.0.3 pycaret-3.0.0 pyod-1.0.9 retrying-1.3.4 schemdraw-0.16 scikit-plot-0.3.7 sktime-0.17.1 tbats-1.1.2 trace-updater-0.0.9.1 wurlitzer-3.0.3 xxhash-3.2.0

# %%
from pycaret.classification import *

# %% [markdown]
# ## **3. 기본 모델링**

# %% [markdown]
# * 세부 요구사항
#     - 최소 4개 이상의 알고리즘을 적용하여 모델링을 수행한다.
#     - 각 알고리즘별로 전체 변수로 모델링, 상위 N개 변수를 선택하여 모델링을 수행하고 성능 비교를 한다.
#     - (옵션) 알고리즘 중 1~2개에 대해서, 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것이다.

# %% [markdown]
# ### (1) 알고리즘1 :

# %%
exp_clf101 = setup(data=data,
                   target=target,
                   fold=5,
                   session_id=123)
# Out:
# <style type="text/css">
# #T_c84f8_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c84f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c84f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c84f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c84f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c84f8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c84f8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c84f8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c84f8_row1_col1" class="data row1 col1" >Activity</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c84f8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c84f8_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c84f8_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_c84f8_row3_col1" class="data row3 col1" >LAYING: 0, SITTING: 1, STANDING: 2, WALKING: 3, WALKING_DOWNSTAIRS: 4, WALKING_UPSTAIRS: 5</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c84f8_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_c84f8_row4_col1" class="data row4 col1" >(5881, 562)</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c84f8_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_c84f8_row5_col1" class="data row5 col1" >(5881, 562)</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c84f8_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_c84f8_row6_col1" class="data row6 col1" >(4116, 562)</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c84f8_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_c84f8_row7_col1" class="data row7 col1" >(1765, 562)</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c84f8_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_c84f8_row8_col1" class="data row8 col1" >561</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c84f8_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c84f8_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c84f8_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c84f8_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c84f8_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c84f8_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c84f8_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c84f8_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c84f8_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_c84f8_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c84f8_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_c84f8_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c84f8_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_c84f8_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c84f8_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_c84f8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c84f8_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_c84f8_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c84f8_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_c84f8_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c84f8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c84f8_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_c84f8_row19_col1" class="data row19 col1" >1344</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 1) 이미 존재하는 metric을 가져와 추가하는 경우
# sklearn에서 제공하는 metric인 log loss를 평가지표로 추가
from sklearn.metrics import log_loss
add_metric('logloss',               # id
           'Log Loss',              # name
            log_loss,               # 함수
            greater_is_better=False # 함수 결과값이 커야 좋은가?
            )
# Out:
# Name                                                       Log Loss
# Display Name                                               Log Loss
# Score Function                <function log_loss at 0x7efe79e70ca0>
# Scorer               make_scorer(log_loss, greater_is_better=False)
# Target                                                         pred
# Args                                                             {}
# Greater is Better                                             False
# Multiclass                                                     True
# Custom                                                         True
# Name: logloss, dtype: object

# %%
get_metrics() # 사용될 평가지표 확인
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
# logloss     Log Loss     Log Loss
#
#                                               Score Function  \
# ID
# acc              <function accuracy_score at 0x7efe79e70280>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa         <function cohen_kappa_score at 0x7efe79e703a0>
# mcc           <function matthews_corrcoef at 0x7efe79e704c0>
# logloss                <function log_loss at 0x7efe79e70ca0>
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# auc        make_scorer(roc_auc_score, needs_proba=True, e...  pred_proba
# recall     make_scorer(recall_score, average=weighted, po...        pred
# precision  make_scorer(precision_score, average=weighted,...        pred
# f1         make_scorer(f1_score, average=weighted, pos_la...        pred
# kappa                         make_scorer(cohen_kappa_score)        pred
# mcc                           make_scorer(matthews_corrcoef)        pred
# logloss       make_scorer(log_loss, greater_is_better=False)        pred
#
#                                                         Args  \
# ID
# acc                                                       {}
# auc            {'average': 'weighted', 'multi_class': 'ovr'}
# recall     {'average': 'weighted', 'pos_label': 'WALKING_...
# precision  {'average': 'weighted', 'pos_label': 'WALKING_...
# f1         {'average': 'weighted', 'pos_label': 'WALKING_...
# kappa                                                     {}
# mcc                                                       {}
# logloss                                                   {}
#
#            Greater is Better  Multiclass  Custom
# ID
# acc                     True        True   False
# auc                     True        True   False
# recall                  True        True   False
# precision               True        True   False
# f1                      True        True   False
# kappa                   True        True   False
# mcc                     True        True   False
# logloss                False        True    True

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_d7222 th {
#   text-align: left;
# }
# #T_d7222_row0_col0, #T_d7222_row1_col0, #T_d7222_row1_col1, #T_d7222_row1_col2, #T_d7222_row1_col3, #T_d7222_row1_col4, #T_d7222_row1_col5, #T_d7222_row1_col6, #T_d7222_row1_col7, #T_d7222_row2_col0, #T_d7222_row2_col1, #T_d7222_row2_col2, #T_d7222_row2_col3, #T_d7222_row2_col4, #T_d7222_row2_col5, #T_d7222_row2_col6, #T_d7222_row2_col7, #T_d7222_row3_col0, #T_d7222_row3_col1, #T_d7222_row3_col2, #T_d7222_row3_col3, #T_d7222_row3_col4, #T_d7222_row3_col5, #T_d7222_row3_col6, #T_d7222_row3_col7, #T_d7222_row4_col0, #T_d7222_row4_col1, #T_d7222_row4_col2, #T_d7222_row4_col3, #T_d7222_row4_col4, #T_d7222_row4_col5, #T_d7222_row4_col6, #T_d7222_row4_col7, #T_d7222_row5_col0, #T_d7222_row5_col1, #T_d7222_row5_col2, #T_d7222_row5_col3, #T_d7222_row5_col4, #T_d7222_row5_col5, #T_d7222_row5_col6, #T_d7222_row5_col7, #T_d7222_row6_col0, #T_d7222_row6_col1, #T_d7222_row6_col2, #T_d7222_row6_col3, #T_d7222_row6_col4, #T_d7222_row6_col5, #T_d7222_row6_col6, #T_d7222_row6_col7, #T_d7222_row7_col0, #T_d7222_row7_col1, #T_d7222_row7_col2, #T_d7222_row7_col3, #T_d7222_row7_col4, #T_d7222_row7_col5, #T_d7222_row7_col6, #T_d7222_row7_col7, #T_d7222_row8_col0, #T_d7222_row8_col1, #T_d7222_row8_col2, #T_d7222_row8_col3, #T_d7222_row8_col4, #T_d7222_row8_col5, #T_d7222_row8_col6, #T_d7222_row8_col7, #T_d7222_row9_col0, #T_d7222_row9_col1, #T_d7222_row9_col2, #T_d7222_row9_col3, #T_d7222_row9_col4, #T_d7222_row9_col5, #T_d7222_row9_col6, #T_d7222_row9_col7, #T_d7222_row10_col0, #T_d7222_row10_col1, #T_d7222_row10_col2, #T_d7222_row10_col3, #T_d7222_row10_col4, #T_d7222_row10_col5, #T_d7222_row10_col6, #T_d7222_row10_col7, #T_d7222_row11_col0, #T_d7222_row11_col1, #T_d7222_row11_col2, #T_d7222_row11_col3, #T_d7222_row11_col4, #T_d7222_row11_col5, #T_d7222_row11_col6, #T_d7222_row11_col7, #T_d7222_row12_col0, #T_d7222_row12_col1, #T_d7222_row12_col2, #T_d7222_row12_col3, #T_d7222_row12_col4, #T_d7222_row12_col5, #T_d7222_row12_col6, #T_d7222_row12_col7, #T_d7222_row13_col0, #T_d7222_row13_col1, #T_d7222_row13_col2, #T_d7222_row13_col3, #T_d7222_row13_col4, #T_d7222_row13_col5, #T_d7222_row13_col6, #T_d7222_row13_col7, #T_d7222_row14_col0, #T_d7222_row14_col1, #T_d7222_row14_col2, #T_d7222_row14_col3, #T_d7222_row14_col4, #T_d7222_row14_col5, #T_d7222_row14_col6, #T_d7222_row14_col7 {
#   text-align: left;
# }
# #T_d7222_row0_col1, #T_d7222_row0_col2, #T_d7222_row0_col3, #T_d7222_row0_col4, #T_d7222_row0_col5, #T_d7222_row0_col6, #T_d7222_row0_col7, #T_d7222_row0_col8, #T_d7222_row1_col8, #T_d7222_row2_col8, #T_d7222_row3_col8, #T_d7222_row4_col8, #T_d7222_row5_col8, #T_d7222_row6_col8, #T_d7222_row7_col8, #T_d7222_row8_col8, #T_d7222_row9_col8, #T_d7222_row10_col8, #T_d7222_row11_col8, #T_d7222_row12_col8, #T_d7222_row13_col8, #T_d7222_row14_col8 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d7222_row0_col9, #T_d7222_row1_col9, #T_d7222_row2_col9, #T_d7222_row3_col9, #T_d7222_row4_col9, #T_d7222_row6_col9, #T_d7222_row7_col9, #T_d7222_row8_col9, #T_d7222_row9_col9, #T_d7222_row10_col9, #T_d7222_row11_col9, #T_d7222_row12_col9, #T_d7222_row13_col9, #T_d7222_row14_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d7222_row5_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d7222" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7222_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d7222_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d7222_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d7222_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d7222_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d7222_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d7222_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d7222_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d7222_level0_col8" class="col_heading level0 col8" >Log Loss</th>
#       <th id="T_d7222_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7222_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_d7222_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d7222_row0_col1" class="data row0 col1" >0.9871</td>
#       <td id="T_d7222_row0_col2" class="data row0 col2" >0.9998</td>
#       <td id="T_d7222_row0_col3" class="data row0 col3" >0.9871</td>
#       <td id="T_d7222_row0_col4" class="data row0 col4" >0.9872</td>
#       <td id="T_d7222_row0_col5" class="data row0 col5" >0.9871</td>
#       <td id="T_d7222_row0_col6" class="data row0 col6" >0.9845</td>
#       <td id="T_d7222_row0_col7" class="data row0 col7" >0.9845</td>
#       <td id="T_d7222_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_d7222_row0_col9" class="data row0 col9" >25.7820</td>
#     </tr>
#     <tr>
#       <th id="T_d7222_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_d7222_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d7222_row1_col1" class="data row1 col1" >0.9837</td>
#       <td id="T_d7222_row1_col2" class="data row1 col2" >0.9995</td>
#       <td id="T_d7222_row1_col3" class="data row1 col3" >0.9837</td>
#       <td id="T_d7222_row1_col4" class="data row1 col4" >0.9838</td>
#       <td id="T_d7222_row1_col5" class="data row1 col5" >0.9837</td>
#       <td id="T_d7222_row1_col6" class="data row1 col6" >0.9804</td>
#       <td id="T_d7222_row1_col7" class="data row1 col7" >0.9804</td>
#       <td id="T_d7222_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_d7222_row1_col9" class="data row1 col9" >72.7660</td>
#     </tr>
#     <tr>
#       <th id="T_d7222_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_d7222_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_d7222_row2_col1" class="data row2 col1" >0.9832</td>
#       <td id="T_d7222_row2_col2" class="data row2 col2" >0.9992</td>
#       <td id="T_d7222_row2_col3" class="data row2 col3" >0.9832</td>
#       <td id="T_d7222_row2_col4" class="data row2 col4" >0.9833</td>
#       <td id="T_d7222_row2_col5" class="data row2 col5" >0.9832</td>
#       <td id="T_d7222_row2_col6" class="data row2 col6" >0.9798</td>
#       <td id="T_d7222_row2_col7" class="data row2 col7" >0.9798</td>
#       <td id="T_d7222_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_d7222_row2_col9" class="data row2 col9" >0.7720</td>
#     </tr>
#     <tr>
#       <th id="T_d7222_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_d7222_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d7222_row3_col1" class="data row3 col1" >0.9815</td>
#       <td id="T_d7222_row3_col2" class="data row3 col2" >0.9996</td>
#       <td id="T_d7222_row3_col3" class="data row3 col3" >0.9815</td>
#       <td id="T_d7222_row3_col4" class="data row3 col4" >0.9817</td>
#       <td id="T_d7222_row3_col5" class="data row3 col5" >0.9815</td>
#       <td id="T_d7222_row3_col6" class="data row3 col6" >0.9778</td>
#       <td id="T_d7222_row3_col7" class="data row3 col7" >0.9778</td>
#       <td id="T_d7222_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_d7222_row3_col9" class="data row3 col9" >44.7820</td>
#     </tr>
#     <tr>
#       <th id="T_d7222_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_d7222_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_d7222_row4_col1" class="data row4 col1" >0.9813</td>
#       <td id="T_d7222_row4_col2" class="data row4 col2" >0.9994</td>
#       <td id="T_d7222_row4_col3" class="data row4 col3" >0.9813</td>
#       <td id="T_d7222_row4_col4" class="data row4 col4" >0.9814</td>
#       <td id="T_d7222_row4_col5" class="data row4 col5" >0.9813</
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
result = pull()
display(result)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9871  0.9998  0.9871  0.9872
# gbc          Gradient Boosting Classifier    0.9837  0.9995  0.9837  0.9838
# lr                    Logistic Regression    0.9832  0.9992  0.9832  0.9833
# xgboost         Extreme Gradient Boosting    0.9815  0.9996  0.9815  0.9817
# et                 Extra Trees Classifier    0.9813  0.9994  0.9813  0.9814
# ridge                    Ridge Classifier    0.9796  0.0000  0.9796  0.9797
# lda          Linear Discriminant Analysis    0.9786  0.9990  0.9786  0.9787
# rf               Random Forest Classifier    0.9694  0.9992  0.9694  0.9696
# svm                   SVM - Linear Kernel    0.9667  0.0000  0.9667  0.9706
# knn                K Neighbors Classifier    0.9514  0.9943  0.9514  0.9521
# dt               Decision Tree Classifier    0.9174  0.9505  0.9174  0.9178
# nb                            Naive Bayes    0.7391  0.9616  0.7391  0.7925
# ada                  Ada Boost Classifier    0.5440  0.8809  0.5440  0.3483
# dummy                    Dummy Classifier    0.1895  0.5000  0.1895  0.0359
# qda       Quadratic Discriminant Analysis    0.1805  0.5212  0.1805  0.0722
#
#               F1   Kappa     MCC  Log Loss  TT (Sec)
# lightgbm  0.9871  0.9845  0.9845       0.0    25.782
# gbc       0.9837  0.9804  0.9804       0.0    72.766
# lr        0.9832  0.9798  0.9798       0.0     0.772
# xgboost   0.9815  0.9778  0.9778       0.0    44.782
# et        0.9813  0.9775  0.9775       0.0     1.372
# ridge     0.9796  0.9754  0.9755       0.0     0.182
# lda       0.9786  0.9743  0.9743       0.0     0.926
# rf        0.9694  0.9632  0.9632       0.0     0.390
# svm       0.9665  0.9599  0.9609       0.0     0.426
# knn       0.9512  0.9415  0.9418       0.0     0.480
# dt        0.9174  0.9006  0.9007       0.0     0.444
# nb        0.7347  0.6868  0.6999       0.0     0.242
# ada       0.4077  0.4446  0.5040       0.0     0.320
# dummy     0.0604  0.0000  0.0000       0.0     0.254
# qda       0.0812  0.0420  0.0920       0.0     0.354
